# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data= pd.read_csv('onlinefoods.csv')
data
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#chech for any duplicates
dup = data.duplicated().any()
print('Are there any duplicates: ',dup)
# Out:
# Are there any duplicates:  True

# %%
#drop all duplicates
data = data.drop_duplicates()

# %%
#check if there are still duplicates
dup = data.duplicated().any()
print('Are there any duplicates: ',dup)
# Out:
# Are there any duplicates:  False

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
#check the ratio of males to females
sns.countplot(x='Gender',data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#check the average age
data['Age'].hist()
# Out:
# <Axes: >

# %%
#check marital status
data['Marital Status'].value_counts()
# Out:
# Marital Status
# Single               189
# Married               87
# Prefer not to say      9
# Name: count, dtype: int64

# %%
sns.countplot(x='Marital Status',data=data)
# Out:
# <Axes: xlabel='Marital Status', ylabel='count'>

# %%
sns.countplot(x='Educational Qualifications', data=data, color='green')
# Out:
# <Axes: xlabel='Educational Qualifications', ylabel='count'>

# %%
#feedback ratio
sns.countplot(x='Feedback',data=data)
# Out:
# <Axes: xlabel='Feedback', ylabel='count'>

# %%
#get the occupation of the dataset
data['Occupation'].value_counts()
# Out:
# Occupation
# Student           144
# Employee           94
# Self Employeed     38
# House wife          9
# Name: count, dtype: int64

# %%
#get the monthly incomes
below_50000 =len(data[data['Monthly Income'].str.contains('Below',case=False)])
print('There are', below_50000, 'that have an income below Rs 50000')
# Out:
# There are 19 that have an income below Rs 50000

# %%
pie = data['Family size'].value_counts()
pie
# Out:
# Family size
# 3    87
# 2    75
# 4    45
# 5    37
# 6    23
# 1    18
# Name: count, dtype: int64

# %%
#family size ratios
plt.pie(pie, labels=pie.index,autopct='%1.1f%%')
plt.show()

# %%
#get the outputs of the data
pie =data['Output'].value_counts()

# %%
plt.pie(pie, labels=pie.index,autopct='%1.1f%%',startangle=140)
plt.show()
